# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
tickers = yf.Tickers("TSLA AAPL MSFT GOOGL BAC MVIS NIO YMAB")

tesla = tickers.tickers['TSLA'].history(period="1mo")
tesla['Open'].plot()
plt.show()
