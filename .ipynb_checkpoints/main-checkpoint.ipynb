# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# tickers = yf.Tickers("TSLA AAPL MSFT GOOGL BAC MVIS NIO YMAB")

# tesla = tickers.tickers['TSLA'].history(period="max")
# tesla.to_csv('Tesla_Stocks.csv')
tesla = pd.read_csv("/home/khoi/Desktop/Stock analysis/Tesla_Stocks.csv", usecols=['Date','Open','High','Low','Close'])

tesla['Date'] = pd.to_datetime(tesla.Date,format='%Y-%m-%d')
tesla.index = tesla['Date']
tesla
# Out:
#                  Date        Open        High         Low       Close
# Date
# 2010-06-29 2010-06-29    3.800000    5.000000    3.508000    4.778000
# 2010-06-30 2010-06-30    5.158000    6.084000    4.660000    4.766000
# 2010-07-01 2010-07-01    5.000000    5.184000    4.054000    4.392000
# 2010-07-02 2010-07-02    4.600000    4.620000    3.742000    3.840000
# 2010-07-06 2010-07-06    4.000000    4.000000    3.166000    3.222000
# ...               ...         ...         ...         ...         ...
# 2021-05-10 2021-05-10  664.900024  665.049988  627.609985  629.039978
# 2021-05-11 2021-05-11  599.239990  627.099976  595.599976  617.200012
# 2021-05-12 2021-05-12  602.489990  620.409973  586.770020  589.890015
# 2021-05-13 2021-05-13  601.539978  606.460022  559.650024  571.690002
# 2021-05-14 2021-05-14  583.409973  592.869995  570.460022  589.739990
#
# [2739 rows x 5 columns]

# %%
closing_prices = tesla.loc[:,'Close']
closing_prices
# Out:
# Date
# 2010-06-29      4.778000
# 2010-06-30      4.766000
# 2010-07-01      4.392000
# 2010-07-02      3.840000
# 2010-07-06      3.222000
#                  ...
# 2021-05-10    629.039978
# 2021-05-11    617.200012
# 2021-05-12    589.890015
# 2021-05-13    571.690002
# 2021-05-14    589.739990
# Name: Close, Length: 2739, dtype: float64

# %%
plt.figure(figsize = (18,9))
plt.plot(range(tesla.shape[0]), tesla['Close'])
plt.xticks(range(0,tesla.shape[0],500),tesla['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Closing Price',fontsize=18)
plt.show()

# %%
dataset = tesla['Close'].values
new_dataset = [[i] for i in dataset]
new_dataset
# Out:
# [[4.777999877929688],
#  [4.765999794006348],
#  [4.392000198364259],
#  [3.839999914169312],
#  [3.2219998836517334],
#  [3.1600000858306885],
#  [3.492000102996826],
#  [3.4800000190734863],
#  [3.4100000858306885],
#  [3.628000020980835],
#  [3.9679999351501465],
#  [3.9779999256134033],
#  [4.127999782562257],
#  [4.381999969482422],
#  [4.059999942779541],
#  [4.044000148773193],
#  [4.199999809265137],
#  [4.257999897003174],
#  [4.190000057220459],
#  [4.110000133514403],
#  [4.144000053405762],
#  [4.070000171661377],
#  [3.98799991607666],
#  [4.184000015258788],
#  [4.389999866485597],
#  [4.251999855041504],
#  [4.0900001525878915],
#  [3.9179999828338623],
#  [3.920000076293945],
#  [3.8059999942779537],
#  [3.5799999237060547],
#  [3.5199999809265137],
#  [3.6640000343322754],
#  [3.75600004196167],
#  [3.829999923706055],
#  [3.753999948501587],
#  [3.757999897003174],
#  [3.8199999332427983],
#  [4.026000022888184],
#  [3.839999914169312],
#  [3.9800000190734863],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(new_dataset)
scaled_data
# Out:
# array([[0.00183878],
#        [0.00182514],
#        [0.00140011],
#        ...,
#        [0.66679167],
#        [0.6461082 ],
#        [0.66662118]])

# %%
import numpy as np
train = tesla[0:2192]
valid = tesla[2192:]
x_train, y_train = [], []
for i in range(300,len(train)):
    x_train.append(scaled_data[i-300:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
# %matplotlib inline

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=7, batch_size=1, verbose=2)
# Out:
# Epoch 1/7
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0067s vs `on_train_batch_end` time: 0.0141s). Check your callbacks.
# 1892/1892 - 33s - loss: 2.8927e-05
# Epoch 2/7
# 1892/1892 - 30s - loss: 1.1504e-05
# Epoch 3/7
# 1892/1892 - 32s - loss: 9.0510e-06
# Epoch 4/7
# 1892/1892 - 32s - loss: 7.2349e-06
# Epoch 5/7
# 1892/1892 - 31s - loss: 6.6517e-06
# Epoch 6/7
# 1892/1892 - 30s - loss: 6.2821e-06
# Epoch 7/7
# 1892/1892 - 31s - loss: 5.8821e-06

# %%
init_inputs = tesla['Close'][len(tesla) - len(valid) - 300:].values
inputs = [[i] for i in init_inputs]

inputs = scaler.transform(inputs)

X_test = []
for i in range(300,inputs.shape[0]):
    X_test.append(inputs[i-300:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
valid['Predictions'] = closing_price

plt.plot(valid[['Close','Predictions']])
valid
# Out:
# <ipython-input-142-b4d7717a288c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price
#                  Date        Open        High         Low       Close  \
# Date
# 2019-03-15 2019-03-15   56.702000   56.743999   54.880001   55.085999
# 2019-03-18 2019-03-18   55.200001   55.610001   53.459999   53.897999
# 2019-03-19 2019-03-19   53.500000   54.660000   52.692001   53.493999
# 2019-03-20 2019-03-20   53.938000   54.993999   53.259998   54.720001
# 2019-03-21 2019-03-21   54.520000   55.290001   53.689999   54.804001
# ...               ...         ...         ...         ...         ...
# 2021-05-10 2021-05-10  664.900024  665.049988  627.609985  629.039978
# ...

# %% [markdown]
# # Note
#
# So far, only Tesla stock is being worked on. However, other stocks will follow the same work, thus perfecting a model for one stock is the goal since this model can then be applied to other stocks.
#
# There are two observations: The higher the epoch number, the more accurate the result. Second, the more days used  to train the model (in my case it was 300 days) the better the results. To improve upon this, I will be trying to incorporate statistics to this model. I have a plan to use news as as source that should affect the results.

# %% [markdown]
# # Plan
# Incorporate different strategies into the model or the results of the model, specifically the predictions column. One way to make this better is to calculate percent error and try to minimize this percentage.

# %%
report = valid.copy()
#positive means predictions > close
#negative means predictions < close
report['error percentage'] = (valid['Close'] - valid['Predictions'])/valid['Close'] * 100
report
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2019-03-15 2019-03-15   56.702000   56.743999   54.880001   55.085999
# 2019-03-18 2019-03-18   55.200001   55.610001   53.459999   53.897999
# 2019-03-19 2019-03-19   53.500000   54.660000   52.692001   53.493999
# 2019-03-20 2019-03-20   53.938000   54.993999   53.259998   54.720001
# 2019-03-21 2019-03-21   54.520000   55.290001   53.689999   54.804001
# ...               ...         ...         ...         ...         ...
# 2021-05-10 2021-05-10  664.900024  665.049988  627.609985  629.039978
# 2021-05-11 2021-05-11  599.239990  627.099976  595.599976  617.200012
# 2021-05-12 2021-05-12  602.489990  620.409973  586.770020  589.890015
# 2021-05-13 2021-05-13  601.539978  606.460022  559.650024  571.690002
# 2021-05-14 2021-05-14  583.409973  592.869995  570.460022  589.739990
#
#             Predictions  error percentage
# Date
# 2019-03-15    56.700546         -2.930958
# ...

# %%
report['error percentage'].plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
errorList = report['error percentage'].values.tolist()
total_negative_nums = list(filter(lambda errorList:errorList<0,errorList))
negAvg = sum(total_negative_nums)/(report['error percentage'] < 0).sum()
total_positive_nums = list(filter(lambda errorList:errorList>0,errorList))
posAvg = sum(total_positive_nums)/(report['error percentage'] > 0).sum()

# %%
#X_test an array of length 547 with each element consisting of an array of length 300
# the first length means the days the model is trying to predict, and the second length means how many days in the past the model uses to predict
# Out:
# array([[[0.06851681],
#         [0.06791904],
#         [0.06836453],
#         ...,
#         [0.06081393],
#         [0.06208675],
#         [0.06231405]],
#
#        [[0.06791904],
#         [0.06836453],
#         [0.0728717 ],
#         ...,
#         [0.06208675],
#         [0.06231405],
#         [0.05901151]],
#
#        [[0.06836453],
#         [0.0728717 ],
#         [0.07225347],
#         ...,
#         [0.06231405],
#         [0.05901151],
#         [0.0576614 ]],
#
#        ...,
#
#        [[0.16676325],
#         [0.16109009],
#         [0.15630334],
#         ...,
#         [0.76052638],
#         [0.71128381],
#         [0.69782823]],
#
#        [[0.16109009],
#         [0.15630334],
#         [0.13460161],
#         ...,
#         [0.71128381],
#         [0.69782823],
#         [0.66679167]],
#
#        [[0.15630334],
#         [0.13460161],
#         [0.14308637],
#         ...,
#         [0.69782823],
#         [0.66679167],
#         [0.6461082 ]]])

# %%
#predicting next day
#however, the percentage error was a lot when I did validation test. I want to now make the model better after the validation test results. How do I do this?
#for now, I will use the model without the improvement

init_predict_inputs = tesla['Close'][len(tesla)-300:].values
predict_inputs = [[i] for i in init_predict_inputs]
predict_inputs = scaler.transform(predict_inputs)
X_predict = []
X_predict.append(predict_inputs[0:300,0])
    
    
X_predict = np.array(X_predict)

X_predict = np.reshape(X_predict, (X_predict.shape[0], 300, 1))
closing_price_prediction = model.predict(X_predict)
closing_price_prediction = scaler.inverse_transform(closing_price_prediction)

# %%
#this new dataframe consists of only new predictions
#to predict the next 100 days, need to use the predicted value of today as input for next day input, and keep repeating this process.

from datetime import date
df = pd.DataFrame([ [date.today(), None, None, None, None, closing_price_prediction[0][0], None ] ], columns=['Date', 'Open', 'High', 'Low', 'Close', 'Predictions','error percentage'])
df['Low closing prediction'] = closing_price_prediction[0][0] * (1+negAvg/100)
df['High closing prediction'] = closing_price_prediction[0][0] * (1+posAvg/100)
df
# Out:
#          Date  Open  High   Low Close  Predictions error percentage  \
# 0  2021-05-20  None  None  None  None   523.595764             None
#
#    Low closing prediction  High closing prediction
# 0              503.918919               560.161077

# %%
#saving model
# model.save('lstm_model.h5')

# %%
# from keras.models import load_model
# model = load_model('lstm_model.h5')
